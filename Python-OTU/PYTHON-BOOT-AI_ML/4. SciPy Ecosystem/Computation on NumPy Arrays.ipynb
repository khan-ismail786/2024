# %% [markdown]
# # Computation on NumPy Arrays

# %% [markdown]
# # Universal Functions

# %% [markdown]
# The NumPy operations can be made fast by converting them into vectorised operations. This is done through the usage of universal functions. NumPy provides convinient interface to the statically typed, compiled routine known as vectorised operations. This approach i designed to push the loop into the compiled layer that is behind the NumPy, which leads to faster execution.

# %% [markdown]
# These operations are defined through ufuncs, which mainly do the quick repeated operations on values in NumPy arrays.

# %% [markdown]
# <b> Arithmetic operations<b>

# %% [markdown]
# Arithmetic operators can be applied directly on the ndarray.

# %%
import numpy as np
a = np.array([1, 2, 3, 4, 5])
a
# Out:
# array([1, 2, 3, 4, 5])

# %%
a + 5  # add five to each array element
# Out:
# array([ 6,  7,  8,  9, 10])

# %%
a - 5
# Out:
# array([-4, -3, -2, -1,  0])

# %%
a * 5
# Out:
# array([ 5, 10, 15, 20, 25])

# %%
a/ 5
# Out:
# array([0.2, 0.4, 0.6, 0.8, 1. ])

# %%
a // 5
# Out:
# array([0, 0, 0, 0, 1])

# %%
a ** 5
# Out:
# array([   1,   32,  243, 1024, 3125])

# %%
a % 5
# Out:
# array([1, 2, 3, 4, 0])

# %%
- a
# Out:
# array([-1, -2, -3, -4, -5])

# %% [markdown]
# Ufuncs are also available for the same operations.

# %%
a
# Out:
# array([1, 2, 3, 4, 5])

# %%
np.add(a, 5)
# Out:
# array([ 6,  7,  8,  9, 10])

# %%
np.subtract(a, 5)
# Out:
# array([-4, -3, -2, -1,  0])

# %%
np.multiply(a, 5)
# Out:
# array([ 5, 10, 15, 20, 25])

# %%
np.divide(a , 5)
# Out:
# array([0.2, 0.4, 0.6, 0.8, 1. ])

# %%
np.floor_divide(a, 5)
# Out:
# array([0, 0, 0, 0, 1])

# %%
11//5
# Out:
# 2

# %%
np.floor_divide(11, 5)
# Out:
# 2

# %%
np.power(a, 5)
# Out:
# array([   1,   32,  243, 1024, 3125])

# %%
np.mod(a, 5)
# Out:
# array([1, 2, 3, 4, 0])

# %%
np.negative(a)
# Out:
# array([-1, -2, -3, -4, -5])

# %% [markdown]
# <b> Absolute function<b>

# %%
a = np.array([-1, 3, -3, 4, -5])

# %%
abs(a)
# Out:
# array([1, 3, 3, 4, 5])

# %%
np.absolute(a)
# Out:
# array([1, 3, 3, 4, 5])

# %%
np.abs(a)
# Out:
# array([1, 3, 3, 4, 5])

# %% [markdown]
# <b> Exponents and Logarithmic functions<b>

# %%
x = np.array([1, 2, 3, 4, 5])

# %%
print("e^x   : " , np.exp(x))
# Out:
# e^x   :  [  2.71828183   7.3890561   20.08553692  54.59815003 148.4131591 ]

# %%
print("2^x   : " , np.exp2(x))
# Out:
# 2^x   :  [ 2.  4.  8. 16. 32.]

# %%
print("3^x   : " , np.power(3, x))
# Out:
# 3^x   :  [  3   9  27  81 243]

# %%
print("ln(x)   : ", np.log(x))
# Out:
# ln(x)   :  [0.         0.69314718 1.09861229 1.38629436 1.60943791]

# %%
print("log2(x)   :  ", np.log2(x))
# Out:
# log2(x)   :   [0.         1.         1.5849625  2.         2.32192809]

# %%
print("log10(x)   :  ", np.log10(x))
# Out:
# log10(x)   :   [0.         0.30103    0.47712125 0.60205999 0.69897   ]

# %% [markdown]
# <b>Operations on multi-dimentional arrays <b>

# %%
x = np.array([[1,2,3], [4, 5, 6]])
x
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
np.add(x, 3)
# Out:
# array([[4, 5, 6],
#        [7, 8, 9]])

# %%
np.subtract(x, 5)
# Out:
# array([[-4, -3, -2],
#        [-1,  0,  1]])

# %%
np.power(x, 2)
# Out:
# array([[ 1,  4,  9],
#        [16, 25, 36]])

# %% [markdown]
# <b> Comparison of ufuncs and for loops <b>

# %%
def find_inverse(narray):
    inverse_list = []
    for number in narray:
        inverse_list.append(1/number)
    return np.array(inverse_list)

# %%
big_array = np.random.randint(1, 100, size=1000)

# %%
# %timeit find_inverse(big_array)
# Out:
# 321 µs ± 2.02 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
# %timeit (1 / big_array)
# Out:
# 2.31 µs ± 33.2 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %%
find_inverse(big_array)
# Out:
# array([0.01785714, 0.33333333, 0.01515152, 0.5       , 0.01724138,
#        0.03225806, 0.01428571, 0.01923077, 0.01282051, 0.125     ,
#        0.03333333, 0.01333333, 0.01111111, 0.03333333, 0.01111111,
#        0.05882353, 0.01724138, 0.11111111, 0.01923077, 0.01282051,
#        0.03030303, 0.02702703, 0.03125   , 0.03571429, 0.01333333,
#        0.02702703, 0.03030303, 0.08333333, 0.01886792, 0.01886792,
#        0.08333333, 0.01369863, 0.02439024, 0.03030303, 0.02631579,
#        0.25      , 0.01075269, 0.02173913, 0.04      , 0.0125    ,
#        0.01149425, 0.01694915, 0.02040816, 0.07142857, 0.03125   ,
#        0.03225806, 0.04545455, 0.01886792, 0.11111111, 0.01587302,
#        0.08333333, 0.01162791, 0.03225806, 0.01075269, 0.01639344,
#        0.25      , 0.01492537, 0.125     , 0.07692308, 0.09090909,
#        0.01136364, 0.01162791, 0.0106383 , 0.01041667, 0.01298701,
#        0.02222222, 0.01818182, 0.02702703, 0.14285714, 0.01538462,
#        0.05555556, 0.02631579, 0.01785714, 0.01176471, 0.02040816,
#        0.25      , 0.02857143, 0.01098901, 0.01960784, 0.01492537,
#        0.01149425, 0.04545455, 0.01176471, 0.03571429, 0.5       ,
#        0.03571429, 0.01041667, 0.01041667, 0.02222222, 0.01086957,
#        0.02173913, 0.01204819, 0.01030928, 0.03125   , 0.08333333,
#        0.01428571, 0.04      , 0.02272727, 0.01149425, 0.0625    ,
#        0.01408451, 0.01369863, 0.09090909, 0.01052632, 0.02222222,
#        0.04545455, 0.01204819, 0.01333333, 0.33333333, 0.01886792,
#        0.04545455, 0.01351351, 0.01234568, 0.05555556, 0.01369863,
#        0.02380952, 0.025     , 0.01111111, 0.0125    , 0.01492537,
#        0.1       , 0.14285714, 0.01612903, 0.03225806, 0.01492537,
#        0.02380952, 0.07142857, 0.05882353, 0.03333333, 0.03571429,
#        0.1       , 0.01234568, 0.02631579, 0.02702703, 0.01886792,
#        0.01030928, 0.04545455, 0.16666667, 0.04      , 0.04545455,
#        0.01724138, 0.01388889, 0.06666667, 0.01369863, 0.02702703,
#        0.01265823, 0.01298701, 0.33333333, 0.01333333, 0.02777778,
#        0.04761905, 0.06666667, 0.01219512, 0.0212766 , 0.07692308,
#        0.125     , 0.14285714, 0.01960784, 0.03571429, 0.5       ,
#        0.01666667, 0.0212766 , 0.01265823, 0.01408451, 0.02564103,
#        0.01041667, 0.25      , 0.02941176, 0.01538462, 0.03333333,
#        0.02325581, 0.0125    , 0.01639344, 0.33333333, 0.02702703,
#        0.01315789, 0.09090909, 0.03030303, 0.2       , 0.04761905,
#        0.33333333, 0.01428571, 0.0125    , 0.01123596, 0.01851852,
#        0.03125   , 0.5       , 0.01886792, 0.02439024, 0.06666667,
#        0.01351351, 0.02941176, 0.01923077, 0.015625  , 0.01639344,
#        0.05      , 0.01020408, 0.02857143, 0.01075269, 0.01041667,
#        0.01176471, 0.03448276, 0.01470588, 0.02941176, 0.04347826,
#        0.03571429, 0.01923077, 0.05555556, 0.015625  , 0.01724138,
#        0.01098901, 0.01666667, 0.05263158, 0.01075269, 0.0125    ,
#        0.03703704, 0.0106383 , 0.01754386, 0.01041667, 0.01123596,
#        0.01111111, 0.025     , 0.01538462, 0.02941176, 0.01219512,
#        0.01612903, 0.02777778, 0.33333333, 0.03448276, 0.05      ,
#        0.01470588, 0.02272727, 0.01612903, 0.01315789, 0.01351351,
#        0.02439024, 0.01515152, 0.05      , 0.025     , 0.02272727,
#        0.01369863, 0.01851852, 0.01818182, 0.01388889, 0.14285714,
#        0.01315789, 0.01639344, 0.01612903, 0.03703704, 0.03030303,
#        0.03125   , 0.01282051, 0.02631579, 0.06666667, 0.03333333,
#        0.08333333, 0.01538462, 0.05555556, 0.02083333, 0.07142857,
#        0.03333333, 0.08333333, 0.01086957, 0.03846154, 0.01123596,
#        0.01075269, 0.01470588, 0.01204819, 0.2       , 0.08333333,
#        0.08333333, 0.01234568, 0.01282051, 0.0625    , 0.01265823,
#        0.03333333, 0.01785714, 0.01785714, 0.01149425, 0.01694915,
#        0.01234568, 0.02272727, 0.02857143, 0.01428571, 0.01162791,
#        1.        , 0.03225806, 0.02702703, 0.05555556, 0.11111111,
#        0.33333333, 0.05882353, 0.01020408, 0.2       , 0.02380952,
#        0.01075269, 0.01123596, 0.03225806, 0.02857143, 0.02222222,
#        0.01020408, 0.03333333, 0.04545455, 0.01010101, 0.01298701,
#        0.01265823, 0.01234568, 0.04761905, 0.01428571, 0.01818182,
#        0.01052632, 1.        , 0.01449275, 0.01587302, 0.04545455,
#        0.0125    , 0.01176471, 0.05263158, 0.02631579, 0.5       ,
#        0.01923077, 0.01204819, 0.02083333, 1.        , 0.01851852,
#        1.        , 0.01449275, 0.01234568, 0.01587302, 0.01515152,
#        0.09090909, 0.01098901, 0.02040816, 0.01030928, 0.03030303,
#        0.25      , 0.01333333, 0.03030303, 0.01470588, 0.01694915,
#        0.07692308, 0.02702703, 0.01010101, 0.0125    , 0.2       ,
#        0.06666667, 0.01785714, 0.01176471, 0.01388889, 0.0125    ,
#        0.5       , 0.01639344, 0.03030303, 0.01136364, 0.03030303,
#        0.0625    , 0.07692308, 0.03125   , 0.25      , 0.01851852])

# %%
1 / big_array
# Out:
# array([0.01785714, 0.33333333, 0.01515152, 0.5       , 0.01724138,
#        0.03225806, 0.01428571, 0.01923077, 0.01282051, 0.125     ,
#        0.03333333, 0.01333333, 0.01111111, 0.03333333, 0.01111111,
#        0.05882353, 0.01724138, 0.11111111, 0.01923077, 0.01282051,
#        0.01298701, 0.01960784, 0.02631579, 0.02857143, 0.03225806,
#        0.01020408, 0.07692308, 0.01492537, 0.01075269, 0.01960784,
#        0.01041667, 0.01190476, 0.01333333, 0.03571429, 0.01369863,
#        0.01351351, 0.01960784, 0.02564103, 0.01298701, 0.02325581,
#        0.09090909, 0.11111111, 0.01724138, 0.01388889, 0.01190476,
#        0.04545455, 0.03448276, 0.33333333, 0.01785714, 0.01754386,
#        0.14285714, 0.01234568, 0.01098901, 0.03571429, 0.01754386,
#        0.015625  , 0.02222222, 0.01052632, 0.04166667, 0.01886792,
#        0.01204819, 0.05      , 0.01315789, 0.02040816, 0.01075269,
#        0.01428571, 0.01960784, 0.01449275, 0.01298701, 0.04545455,
#        0.01041667, 0.01010101, 0.01075269, 0.02380952, 0.0106383 ,
#        0.01086957, 0.25      , 0.02439024, 0.01298701, 0.04761905,
#        0.02702703, 0.01111111, 0.01492537, 0.01923077, 0.01851852,
#        0.02173913, 0.02631579, 0.0212766 , 0.25      , 0.125     ,
#        0.01515152, 0.01052632, 0.01111111, 0.01886792, 0.01204819,
#        0.01851852, 0.01030928, 0.02631579, 0.02325581, 0.05263158,
#        0.02631579, 0.01010101, 0.03846154, 0.01123596, 0.01219512,
#        0.03703704, 0.09090909, 0.25      , 0.02564103, 0.02083333,
#        0.01086957, 0.33333333, 0.01265823, 0.01086957, 0.02      ,
#        0.01298701, 0.01666667, 0.05263158, 0.02173913, 0.02439024,
#        0.015625  , 0.01075269, 0.01190476, 0.01075269, 0.01960784,
#        0.02272727, 0.03125   , 0.01818182, 0.01041667, 0.01204819,
#        0.03225806, 0.01030928, 0.05882353, 0.03571429, 0.02325581,
#        0.03225806, 0.01515152, 0.01219512, 0.04347826, 0.01470588,
#        1.        , 0.04166667, 0.01818182, 0.01020408, 0.04347826,
#        0.01176471, 0.01886792, 0.01724138, 0.0625    , 0.01538462,
#        0.03703704, 0.01351351, 0.01428571, 0.01666667, 0.03448276,
#        0.07142857, 0.01388889, 0.04545455, 0.01851852, 0.03846154,
#        0.2       , 0.02083333, 0.01282051, 0.03030303, 0.01123596,
#        0.03333333, 0.02325581, 0.0212766 , 0.01315789, 0.01694915,
#        0.01785714, 0.04761905, 0.01219512, 0.01315789, 0.01923077,
#        0.01219512, 0.01960784, 0.02      , 0.01086957, 0.015625  ,
#        0.33333333, 0.02380952, 0.02325581, 0.02222222, 0.08333333,
#        0.03571429, 0.1       , 0.04      , 0.01754386, 0.125     ,
#        0.01234568, 0.125     , 0.01492537, 0.01470588, 0.01612903,
#        0.05263158, 0.01282051, 0.01234568, 0.02439024, 0.1       ,
#        0.02173913, 0.01369863, 0.01149425, 0.01111111, 0.02941176,
#        1.        , 0.01351351, 0.125     , 0.01075269, 0.02857143,
#        0.01282051, 0.04545455, 0.01754386, 0.01492537, 0.03448276,
#        0.02631579, 0.01190476, 0.02      , 0.01176471, 0.05      ,
#        0.01612903, 0.02702703, 0.015625  , 0.01219512, 0.01098901,
#        0.01388889, 0.07692308, 0.01075269, 0.02222222, 0.05882353,
#        0.02941176, 0.04761905, 0.01315789, 0.01587302, 0.01098901,
#        0.03030303, 0.04545455, 0.01408451, 0.0125    , 0.2       ,
#        0.025     , 0.03125   , 0.02777778, 0.01190476, 0.09090909,
#        0.2       , 0.01298701, 0.01234568, 0.0106383 , 0.01754386,
#        0.01538462, 0.05263158, 0.025     , 0.14285714, 0.03030303,
#        0.04761905, 0.02272727, 0.01333333, 0.01190476, 0.01176471,
#        0.01052632, 0.02439024, 0.01162791, 0.03703704, 0.08333333,
#        0.04545455, 0.0625    , 0.02040816, 0.01086957, 0.02173913,
#        0.02222222, 0.03333333, 0.04166667, 0.01851852, 0.33333333,
#        0.09090909, 0.01052632, 0.02702703, 0.03703704, 0.16666667,
#        0.02083333, 0.01298701, 0.01694915, 0.01639344, 0.01449275,
#        0.01388889, 0.01886792, 0.01923077, 0.01020408, 0.01136364,
#        0.01041667, 0.01149425, 0.2       , 0.05263158, 0.01149425,
#        0.01886792, 0.2       , 0.01960784, 0.01298701, 0.01923077,
#        0.01587302, 0.01136364, 1.        , 0.02631579, 0.03125   ,
#        0.02631579, 0.015625  , 0.02631579, 0.01333333, 0.02      ,
#        0.01315789, 0.03030303, 0.5       , 0.01075269, 0.01052632,
#        0.0125    , 0.16666667, 0.03225806, 0.01639344, 0.01694915,
#        0.01111111, 0.0125    , 0.02380952, 0.0125    , 0.01149425,
#        0.02631579, 1.        , 0.01694915, 1.        , 0.01111111,
#        0.08333333, 0.01694915, 0.03703704, 0.02380952, 0.125     ,
#        0.01315789, 0.01449275, 0.04761905, 0.01449275, 0.02272727,
#        0.05555556, 0.01052632, 0.09090909, 0.01075269, 0.01388889,
#        0.01587302, 0.02272727, 0.01010101, 0.05882353, 0.02564103,
#        0.025     , 0.02439024, 0.04      , 0.01449275, 0.01538462,
#        0.01219512, 0.01492537, 0.01020408, 0.01449275, 0.125     ,
#        0.01587302, 0.01428571, 0.1       , 0.02941176, 0.33333333,
#        0.04166667, 0.01818182, 0.01315789, 0.1       , 0.02631579,
#        0.01052632, 0.01351351, 0.04545455, 0.02777778, 0.015625  ,
#        0.14285714, 0.02380952, 0.02777778, 0.01282051, 0.03571429,
#        0.16666667, 0.02222222, 0.02380952, 0.1       , 0.02083333,
#        1.        , 0.01111111, 0.03571429, 0.03703704, 0.03448276,
#        0.02941176, 0.01282051, 0.25      , 0.04761905, 0.04      ,
#        0.0212766 , 0.01449275, 0.01190476, 0.03448276, 0.0125    ,
#        0.33333333, 0.01136364, 0.01219512, 0.01851852, 0.03333333,
#        0.08333333, 0.01030928, 0.05      , 0.01219512, 0.5       ,
#        0.5       , 0.015625  , 0.04545455, 0.01851852, 0.01333333,
#        0.03571429, 0.02      , 0.01612903, 0.01098901, 0.05      ,
#        0.02941176, 0.02631579, 0.01234568, 0.01428571, 0.04545455,
#        0.01538462, 0.33333333, 0.05555556, 0.04545455, 0.05      ,
#        0.01020408, 0.01020408, 0.09090909, 0.02272727, 0.01754386,
#        0.01086957, 0.02702703, 0.01639344, 0.0625    , 0.01886792,
#        0.03333333, 0.11111111, 0.02702703, 0.01052632, 0.01298701,
#        0.03846154, 0.02173913, 0.0125    , 0.03448276, 0.02777778,
#        0.11111111, 0.01098901, 0.01333333, 0.16666667, 0.01075269,
#        0.01020408, 0.01190476, 0.5       , 0.01265823, 0.03333333,
#        0.25      , 0.01351351, 0.02941176, 0.01449275, 0.16666667,
#        0.01408451, 0.05555556, 0.16666667, 0.01515152, 0.01298701,
#        0.14285714, 0.01449275, 0.03448276, 0.02      , 0.01041667,
#        0.02380952, 0.01098901, 0.1       , 0.01960784, 0.03125   ,
#        0.01923077, 0.03030303, 0.07692308, 0.2       , 0.04761905,
#        0.02040816, 0.03571429, 0.11111111, 0.02702703, 0.16666667,
#        0.01449275, 0.08333333, 0.05263158, 0.01315789, 0.01449275,
#        0.03225806, 0.03030303, 0.01075269, 0.03030303, 0.01666667,
#        0.01315789, 0.14285714, 0.05263158, 0.02083333, 0.02777778,
#        0.01020408, 0.01030928, 0.03225806, 0.01086957, 0.04347826,
#        0.04      , 0.03846154, 0.01149425, 0.01111111, 0.07142857,
#        0.2       , 0.01190476, 0.03333333, 0.02941176, 0.02941176,
#        0.01818182, 0.01190476, 0.01052632, 0.11111111, 0.01282051,
#        0.04166667, 0.11111111, 0.025     , 0.01098901, 0.11111111,
#        0.01086957, 0.015625  , 0.04166667, 0.05      , 0.02564103,
#        0.01408451, 0.025     , 0.01333333, 0.01515152, 0.01851852,
#        0.02222222, 0.04545455, 0.01492537, 0.09090909, 0.02631579,
#        0.01219512, 0.01010101, 0.02272727, 0.02222222, 1.        ,
#        0.01219512, 0.03571429, 0.14285714, 0.01075269, 0.01960784,
#        0.0106383 , 0.01020408, 0.05882353, 0.01369863, 0.0125    ,
#        0.04      , 0.0106383 , 0.01086957, 0.03333333, 0.02      ,
#        0.0212766 , 0.01020408, 0.03333333, 0.01136364, 0.03030303,
#        0.01724138, 0.01086957, 0.06666667, 0.01666667, 0.02040816,
#        0.16666667, 0.05263158, 0.01538462, 0.03225806, 0.01176471,
#        0.08333333, 0.01176471, 0.01190476, 0.11111111, 0.05555556,
#        0.0106383 , 0.05      , 0.04347826, 0.04      , 0.03846154,
#        0.01041667, 0.25      , 0.02941176, 0.01538462, 0.03333333,
#        0.02325581, 0.0125    , 0.01639344, 0.33333333, 0.02702703,
#        0.01315789, 0.09090909, 0.03030303, 0.2       , 0.04761905,
#        0.33333333, 0.01428571, 0.0125    , 0.01123596, 0.01851852,
#        0.03125   , 0.5       , 0.01886792, 0.02439024, 0.06666667,
#        0.01351351, 0.02941176, 0.01923077, 0.015625  , 0.01639344,
#        0.05      , 0.01020408, 0.02857143, 0.01075269, 0.01041667,
#        0.01176471, 0.03448276, 0.01470588, 0.02941176, 0.04347826,
#        0.03571429, 0.01923077, 0.05555556, 0.015625  , 0.01724138,
#        0.01098901, 0.01666667, 0.05263158, 0.01075269, 0.0125    ,
#        0.03703704, 0.0106383 , 0.01754386, 0.01041667, 0.01123596,
#        0.01111111, 0.025     , 0.01538462, 0.02941176, 0.01219512,
#        0.01612903, 0.02777778, 0.33333333, 0.03448276, 0.05      ,
#        0.01470588, 0.02272727, 0.01612903, 0.01315789, 0.01351351,
#        0.02439024, 0.01515152, 0.05      , 0.025     , 0.02272727,
#        0.01369863, 0.01851852, 0.01818182, 0.01388889, 0.14285714,
#        0.01315789, 0.01639344, 0.01612903, 0.03703704, 0.03030303,
#        0.03125   , 0.01282051, 0.02631579, 0.06666667, 0.03333333,
#        0.08333333, 0.01538462, 0.05555556, 0.02083333, 0.07142857,
#        0.03333333, 0.08333333, 0.01086957, 0.03846154, 0.01123596,
#        0.01075269, 0.01470588, 0.01204819, 0.2       , 0.08333333,
#        0.08333333, 0.01234568, 0.01282051, 0.0625    , 0.01265823,
#        0.03333333, 0.01785714, 0.01785714, 0.01149425, 0.01694915,
#        0.01234568, 0.02272727, 0.02857143, 0.01428571, 0.01162791,
#        1.        , 0.03225806, 0.02702703, 0.05555556, 0.11111111,
#        0.33333333, 0.05882353, 0.01020408, 0.2       , 0.02380952,
#        0.01075269, 0.01123596, 0.03225806, 0.02857143, 0.02222222,
#        0.01020408, 0.03333333, 0.04545455, 0.01010101, 0.01298701,
#        0.01265823, 0.01234568, 0.04761905, 0.01428571, 0.01818182,
#        0.01052632, 1.        , 0.01449275, 0.01587302, 0.04545455,
#        0.0125    , 0.01176471, 0.05263158, 0.02631579, 0.5       ,
#        0.01923077, 0.01204819, 0.02083333, 1.        , 0.01851852,
#        1.        , 0.01449275, 0.01234568, 0.01587302, 0.01515152,
#        0.09090909, 0.01098901, 0.02040816, 0.01030928, 0.03030303,
#        0.25      , 0.01333333, 0.03030303, 0.01470588, 0.01694915,
#        0.07692308, 0.02702703, 0.01010101, 0.0125    , 0.2       ,
#        0.06666667, 0.01785714, 0.01176471, 0.01388889, 0.0125    ,
#        0.5       , 0.01639344, 0.03030303, 0.01136364, 0.03030303,
#        0.0625    , 0.07692308, 0.03125   , 0.25      , 0.01851852])

# %% [markdown]
# <b> Comparision operators<b>

# %% [markdown]
# Comparison operators are also vectorisd operations.

# %%
x = np.array([1, 2, 3, 4, 5])
x
# Out:
# array([1, 2, 3, 4, 5])

# %%
x < 5
# Out:
# array([ True,  True,  True,  True, False])

# %%
x > 5
# Out:
# array([False, False, False, False, False])

# %%
x == 5
# Out:
# array([False, False, False, False,  True])

# %%
x != 5
# Out:
# array([ True,  True,  True,  True, False])

# %%
x <=5
# Out:
# array([ True,  True,  True,  True,  True])

# %%
x >=5
# Out:
# array([False, False, False, False,  True])

# %% [markdown]
# ufuncs are also available for comparison operators.

# %%
x
# Out:
# array([1, 2, 3, 4, 5])

# %%
np.equal(x, 5)
# Out:
# array([False, False, False, False,  True])

# %%
np.not_equal(x, 5)
# Out:
# array([ True,  True,  True,  True, False])

# %%
np.less(x, 5)
# Out:
# array([ True,  True,  True,  True, False])

# %%
np.greater(x, 5)
# Out:
# array([False, False, False, False, False])

# %%
x >= 5
# Out:
# array([False, False, False, False,  True])

# %%
np.greater_equal(x, 5)
# Out:
# array([False, False, False, False,  True])

# %%
np.less_equal(x, 5)
# Out:
# array([ True,  True,  True,  True,  True])

# %% [markdown]
# <b> Boolean Ufuncs<b>

# %%
np.random.random(size=(3,4))
# Out:
# array([[0.5700585 , 0.75159836, 0.942816  , 0.31413748],
#        [0.85230667, 0.96582697, 0.49540535, 0.11749505],
#        [0.17877492, 0.81983702, 0.43064496, 0.7528582 ]])

# %%
x = np.random.randint(10, size=(3,4))
x
# Out:
# array([[5, 8, 8, 0],
#        [9, 2, 7, 8],
#        [5, 8, 5, 2]])

# %% [markdown]
# We can use comparison operator like <, > etc on this array directly.

# %%
x > 5
# Out:
# array([[ True, False, False, False],
#        [False, False,  True,  True],
#        [False,  True,  True,  True]])

# %% [markdown]
# The outcome matrix contains True/False for every element present in original matrix.

# %% [markdown]
# Following Ufuncs and boolean operators can be used on matrices.

# %%
#counting number of elements fullfilling the condition
np.sum(x < 5)   # 6 entries in matrix which are less than 5
# Out:
# 3

# %%
#counting number of elements fullfilling the condition, for each row
np.sum(x <= 5, axis = 1)   # 6 entries in matrix which are less than 5
# Out:
# array([2, 1, 3])

# %% [markdown]
# First row contains 3 elements, second row has one element whereas the third row has two elments fullfilling the condition.

# %%
#counting number of elements fullfilling the condition, for each row
np.sum(x < 5, axis = 0)   # 6 entries in matrix which are less than 5
# Out:
# array([0, 1, 0, 2])

# %% [markdown]
# First column contains 2 elements, second column has two element whereas the third column has one elments , fourth column contains one element fullfilling the condition.

# %% [markdown]
# One can determine whether any or all the values are true , np.any() and np.all() can be used.

# %%
np.all(x > 5)
# Out:
# False

# %% [markdown]
# Same operations can be done on row or column basis.

# %%
#Check for every row whether any value is greater than 5 or not
np.any(x > 5, axis = 1)
# Out:
# array([ True,  True,  True])

# %%
#Check for every column whether any value is greater than 5 or not
np.any(x > 5, axis = 0)
# Out:
# array([ True,  True,  True,  True])

# %% [markdown]
# <b> Boolean Operators<b>

# %% [markdown]
# Logical operators like &, ~ and | can be used as part of conditions.

# %%
x
# Out:
# array([[5, 8, 8, 0],
#        [9, 2, 7, 8],
#        [5, 8, 5, 2]])

# %%
#Determine how many elements have value greater than 5 and less than 8
np.sum( ( x > 5 ) & (x < 8))
# Out:
# 1

# %%
#Determine how many elements have value equal t0 5 or 8
np.sum( ( x == 5 ) | (x == 8))
# Out:
# 7

# %%
#Determine how many elements does not fullfill the given condition
np.sum( ~(( x == 5 ) | (x == 8)))
# Out:
# 5

# %% [markdown]
# <b>Masking using Boolean Arrays <b>

# %%
x
# Out:
# array([[0, 4, 0, 5],
#        [7, 5, 7, 0],
#        [0, 4, 8, 8]])

# %% [markdown]
# Now need to find out how many elements have value less than 4.

# %%
x < 8
# Out:
# array([[ True, False, False,  True],
#        [False,  True,  True, False],
#        [ True, False,  True,  True]])

# %% [markdown]
# But how to extract the actaul element values those are less than 8? This can be done using the indexing. This is called as masking.

# %%
x[ x < 8]  # returns one dimensional array having values less than 8
# Out:
# array([5, 0, 2, 7, 5, 5, 2])

# %% [markdown]
# Masks can be defined and used as part of ufuncs.

# %%
#Define a mask i.e. a condition based on which elements needs to be extracted
my_mask = x < 8

# %%
#Use mask in the place of indexing
x[my_mask]
# Out:
# array([5, 0, 2, 7, 5, 5, 2])

# %% [markdown]
# Masks can be complicated conditions as well.

# %%
my_mask = (x < 8 ) & (x > 5)

# %%
#Use mask in the place of indexing
x[my_mask]
# Out:
# array([7])
